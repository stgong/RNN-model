# %% [markdown]
# ### model.fit() fine tune the RNN hidden layer parameter
# #### layers = [200, 250, 300,'200-100','300-200','200-100-50', '300-200-100']

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --r_emb 100 --min_iter 10 --r_l 50
# Out:
# 2019-12-09 15:57:00.267028: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-09 15:57:00.295355: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 1895585000 Hz
# 2019-12-09 15:57:00.295825: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3eb8860 executing computations on platform Host. Devices:
# 2019-12-09 15:57:00.295858: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 177316 samples, validate on 629 samples
# Epoch 1/10
#
# Epoch 00001: val_loss improved from inf to 6.91449, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne5.612_gc100_e100_h50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 429s - loss: 6.9506 - val_loss: 6.9145
# Epoch 2/10
#
# Epoch 00002: val_loss improved from 6.91449 to 6.86076, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne5.612_gc100_e100_h50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 430s - loss: 6.8876 - val_loss: 6.8608
# Epoch 3/10
#
# Epoch 00003: val_loss improved from 6.86076 to 6.81939, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne5.612_gc100_e100_h50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 428s - loss: 6.8183 - val_loss: 6.8194
# Epoch 4/10
#
# Epoch 00004: val_loss improved from 6.81939 to 6.79989, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne5.612_gc100_e100_h50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 430s - loss: 6.7752 - val_loss: 6.7999
# Epoch 5/10
#
# Epoch 00005: val_loss improved from 6.79989 to 6.74083, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne5.612_gc100_e100_h50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 424s - loss: 6.7134 - val_loss: 6.7408
# Epoch 6/10
#
# Epoch 00006: val_loss did not improve from 6.74083
# 177316/177316 - 424s - loss: 6.6569 - val_loss: 6.7849
# Epoch 7/10
#
# Epoch 00007: val_loss improved from 6.74083 to 6.66563, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne5.612_gc100_e100_h50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 227s - loss: 6.6179 - val_loss: 6.6656
# Epoch 8/10
#
# Epoch 00008: val_loss improved from 6.66563 to 6.60986, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne5.612_gc100_e100_h50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 208s - loss: 6.5783 - val_loss: 6.6099
# Epoch 9/10
#
# Epoch 00009: val_loss improved from 6.60986 to 6.58221, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne5.612_gc100_e100_h50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 207s - loss: 6.5438 - val_loss: 6.5822
# Epoch 10/10
#
# Epoch 00010: val_loss improved from 6.58221 to 6.56241, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne5.612_gc100_e100_h50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 207s - loss: 6.5134 - val_loss: 6.5624
# [6.9505853026479425, 6.887643634147552, 6.818264943526264, 6.775199862072288, 6.713418472310434, 6.656895385889684, 6.617880190095663, 6.57827057223475, 6.543843463120721, 6.513425022484004]
# Opening file (1)
# RNN with categorical cross entropy 0 batchs,  3414.811716556549  epochs in 3418.7417788505554 s
# Last train cost :  6.705542684852931
# recall :  0.04969008565897106
# precision :  0.08171701112877616
# sps :  0.05564387917329094
# Best  sps :  0.05564387917329094
# user_coverage :  0.5405405405405406
# item_coverage :  120
# ndcg :  0.08365281742562573
# blockbuster_share :  0.4046692607003891
# -----------------
# Save model in ks-cooks-1y/models/rnn_cce_ml60_bs32_ne3414.812_gc100_e100_h50_Ug_lr0.1_nt1.hdf5

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --r_emb 100 --min_iter 10 --r_l 100
# Out:
# 2019-12-09 16:54:11.748848: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-09 16:54:11.771390: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 1895585000 Hz
# 2019-12-09 16:54:11.771806: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x47c5b60 executing computations on platform Host. Devices:
# 2019-12-09 16:54:11.771830: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 177316 samples, validate on 629 samples
# Epoch 1/10
#
# Epoch 00001: val_loss improved from inf to 6.89787, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne3.034_gc100_e100_h100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 339s - loss: 6.9475 - val_loss: 6.8979
# Epoch 2/10
#
# Epoch 00002: val_loss improved from 6.89787 to 6.86583, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne3.034_gc100_e100_h100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 342s - loss: 6.8887 - val_loss: 6.8658
# Epoch 3/10
#
# Epoch 00003: val_loss improved from 6.86583 to 6.80237, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne3.034_gc100_e100_h100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 343s - loss: 6.8148 - val_loss: 6.8024
# Epoch 4/10
#
# Epoch 00004: val_loss improved from 6.80237 to 6.74674, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne3.034_gc100_e100_h100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 344s - loss: 6.7142 - val_loss: 6.7467
# Epoch 5/10
#
# Epoch 00005: val_loss improved from 6.74674 to 6.71729, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne3.034_gc100_e100_h100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 345s - loss: 6.6636 - val_loss: 6.7173
# Epoch 6/10
#
# Epoch 00006: val_loss did not improve from 6.71729
# 177316/177316 - 345s - loss: 6.6290 - val_loss: 6.7444
# Epoch 7/10
#
# Epoch 00007: val_loss improved from 6.71729 to 6.62308, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne3.034_gc100_e100_h100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 347s - loss: 6.5902 - val_loss: 6.6231
# Epoch 8/10
#
# Epoch 00008: val_loss improved from 6.62308 to 6.61598, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne3.034_gc100_e100_h100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 347s - loss: 6.5504 - val_loss: 6.6160
# Epoch 9/10
#
# Epoch 00009: val_loss improved from 6.61598 to 6.59668, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne3.034_gc100_e100_h100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 351s - loss: 6.5121 - val_loss: 6.5967
# Epoch 10/10
#
# Epoch 00010: val_loss improved from 6.59668 to 6.56300, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne3.034_gc100_e100_h100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 370s - loss: 6.4772 - val_loss: 6.5630
# [6.947546928331066, 6.888669213988559, 6.814819967005324, 6.714164287717131, 6.663597054644902, 6.6289968431653445, 6.5902284861616724, 6.55042389397661, 6.512079290717752, 6.477245132670719]
# Opening file (1)
# RNN with categorical cross entropy 0 batchs,  3473.664969921112  epochs in 3477.8817055225372 s
# Last train cost :  6.678777109837908
# recall :  0.04987941433691286
# precision :  0.08251192368839459
# sps :  0.0492845786963434
# Best  sps :  0.0492845786963434
# user_coverage :  0.5214626391096979
# item_coverage :  145
# ndcg :  0.08413690612880768
# blockbuster_share :  0.4026974951830443
# -----------------
# Save model in ks-cooks-1y/models/rnn_cce_ml60_bs32_ne3473.665_gc100_e100_h100_Ug_lr0.1_nt1.hdf5

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --r_emb 100 --min_iter 10 --r_l 150
# Out:
# 2019-12-09 17:52:16.054993: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-09 17:52:16.079351: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 1895585000 Hz
# 2019-12-09 17:52:16.079884: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x4a70e30 executing computations on platform Host. Devices:
# 2019-12-09 17:52:16.079927: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 177316 samples, validate on 629 samples
# Epoch 1/10
#
# Epoch 00001: val_loss improved from inf to 6.90703, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.953_gc100_e100_h150_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 553s - loss: 6.9483 - val_loss: 6.9070
# Epoch 2/10
#
# Epoch 00002: val_loss improved from 6.90703 to 6.88392, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.953_gc100_e100_h150_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 529s - loss: 6.9097 - val_loss: 6.8839
# Epoch 3/10
#
# Epoch 00003: val_loss improved from 6.88392 to 6.83006, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.953_gc100_e100_h150_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 542s - loss: 6.8466 - val_loss: 6.8301
# Epoch 4/10
#
# Epoch 00004: val_loss improved from 6.83006 to 6.81455, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.953_gc100_e100_h150_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 559s - loss: 6.7962 - val_loss: 6.8145
# Epoch 5/10
#
# Epoch 00005: val_loss improved from 6.81455 to 6.74201, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.953_gc100_e100_h150_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 551s - loss: 6.7481 - val_loss: 6.7420
# Epoch 6/10
#
# Epoch 00006: val_loss did not improve from 6.74201
# 177316/177316 - 519s - loss: 6.6896 - val_loss: 6.8121
# Epoch 7/10
#
# Epoch 00007: val_loss improved from 6.74201 to 6.68832, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.953_gc100_e100_h150_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 522s - loss: 6.6462 - val_loss: 6.6883
# Epoch 8/10
#
# Epoch 00008: val_loss improved from 6.68832 to 6.64766, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.953_gc100_e100_h150_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 523s - loss: 6.6077 - val_loss: 6.6477
# Epoch 9/10
#
# Epoch 00009: val_loss improved from 6.64766 to 6.60871, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.953_gc100_e100_h150_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 524s - loss: 6.5624 - val_loss: 6.6087
# Epoch 10/10
#
# Epoch 00010: val_loss improved from 6.60871 to 6.59744, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.953_gc100_e100_h150_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 519s - loss: 6.5234 - val_loss: 6.5974
# [6.948329517026997, 6.909728852515373, 6.846600508124612, 6.796183008976504, 6.7480966653445, 6.689596173555078, 6.646223482792725, 6.607693014338735, 6.562438136991451, 6.523436572400111]
# Opening file (1)
# RNN with categorical cross entropy 0 batchs,  5339.612893342972  epochs in 5344.288603782654 s
# Last train cost :  6.7278325932066085
# recall :  0.04739114081843512
# precision :  0.07742448330683659
# sps :  0.05564387917329094
# Best  sps :  0.05564387917329094
# user_coverage :  0.5119236883942766
# item_coverage :  127
# ndcg :  0.08207043619646637
# blockbuster_share :  0.42505133470225875
# -----------------
# Save model in ks-cooks-1y/models/rnn_cce_ml60_bs32_ne5339.613_gc100_e100_h150_Ug_lr0.1_nt1.hdf5

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --r_emb 100 --min_iter 10 --r_l 200
# Out:
# 2019-12-09 19:21:26.862985: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-09 19:21:26.887522: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 1895585000 Hz
# 2019-12-09 19:21:26.888134: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x449f830 executing computations on platform Host. Devices:
# 2019-12-09 19:21:26.888172: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 177316 samples, validate on 629 samples
# Epoch 1/10
#
# Epoch 00001: val_loss improved from inf to 6.90229, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.922_gc100_e100_h200_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 751s - loss: 6.9494 - val_loss: 6.9023
# Epoch 2/10
#
# Epoch 00002: val_loss improved from 6.90229 to 6.86934, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.922_gc100_e100_h200_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 755s - loss: 6.8909 - val_loss: 6.8693
# Epoch 3/10
#
# Epoch 00003: val_loss improved from 6.86934 to 6.81452, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.922_gc100_e100_h200_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 755s - loss: 6.8225 - val_loss: 6.8145
# Epoch 4/10
#
# Epoch 00004: val_loss did not improve from 6.81452
# 177316/177316 - 755s - loss: 6.7835 - val_loss: 6.8238
# Epoch 5/10
#
# Epoch 00005: val_loss did not improve from 6.81452
# 177316/177316 - 760s - loss: 6.7202 - val_loss: 6.8201
# Epoch 6/10
#
# Epoch 00006: val_loss improved from 6.81452 to 6.80907, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.922_gc100_e100_h200_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 786s - loss: 6.6619 - val_loss: 6.8091
# Epoch 7/10
#
# Epoch 00007: val_loss improved from 6.80907 to 6.66864, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.922_gc100_e100_h200_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 763s - loss: 6.6265 - val_loss: 6.6686
# Epoch 8/10
#
# Epoch 00008: val_loss improved from 6.66864 to 6.61668, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.922_gc100_e100_h200_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 754s - loss: 6.5887 - val_loss: 6.6167
# Epoch 9/10
#
# Epoch 00009: val_loss improved from 6.61668 to 6.58330, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.922_gc100_e100_h200_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 752s - loss: 6.5442 - val_loss: 6.5833
# Epoch 10/10
#
# Epoch 00010: val_loss improved from 6.58330 to 6.55623, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.922_gc100_e100_h200_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 800s - loss: 6.5039 - val_loss: 6.5562
# [6.9494117417964025, 6.890933033082354, 6.822521994509717, 6.783513494024001, 6.720240228699811, 6.661888461181927, 6.626532077455846, 6.588718507234435, 6.5442146199166205, 6.503948398966919]
# Opening file (1)
# RNN with categorical cross entropy 0 batchs,  7632.4716720581055  epochs in 7637.7712988853455 s
# Last train cost :  6.709192255686804
# recall :  0.048107226019547145
# precision :  0.0790143084260735
# sps :  0.046104928457869634
# Best  sps :  0.046104928457869634
# user_coverage :  0.5151033386327504
# item_coverage :  130
# ndcg :  0.08179594735646538
# blockbuster_share :  0.4084507042253521
# -----------------
# Save model in ks-cooks-1y/models/rnn_cce_ml60_bs32_ne7632.472_gc100_e100_h200_Ug_lr0.1_nt1.hdf5

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --r_emb 100 --min_iter 10 --r_l 300 --r_emb_opt lstm
# Out:
# 2019-12-09 22:29:41.054782: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-09 22:29:41.083405: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 1895585000 Hz
# 2019-12-09 22:29:41.084108: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x41e0eb0 executing computations on platform Host. Devices:
# 2019-12-09 22:29:41.084161: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 177316 samples, validate on 629 samples
# Epoch 1/10
#
# Epoch 00001: val_loss improved from inf to 6.84008, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne3.347_gc100_e100_h300_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 1160s - loss: 6.9228 - val_loss: 6.8401
# Epoch 2/10
# ^C

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --r_emb 100 --min_iter 10 --r_l 100-50
# Out:
# 2019-12-09 22:55:56.173385: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-09 22:55:56.195331: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 1895585000 Hz
# 2019-12-09 22:55:56.195644: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x397e9f0 executing computations on platform Host. Devices:
# 2019-12-09 22:55:56.195675: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 177316 samples, validate on 629 samples
# Epoch 1/10
#
# Epoch 00001: val_loss improved from inf to 6.88671, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.934_gc100_e100_h100-50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 533s - loss: 6.9410 - val_loss: 6.8867
# Epoch 2/10
#
# Epoch 00002: val_loss improved from 6.88671 to 6.85058, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.934_gc100_e100_h100-50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 522s - loss: 6.8918 - val_loss: 6.8506
# Epoch 3/10
#
# Epoch 00003: val_loss improved from 6.85058 to 6.82951, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.934_gc100_e100_h100-50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 513s - loss: 6.8224 - val_loss: 6.8295
# Epoch 4/10
#
# Epoch 00004: val_loss improved from 6.82951 to 6.77999, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.934_gc100_e100_h100-50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 512s - loss: 6.7660 - val_loss: 6.7800
# Epoch 5/10
#
# Epoch 00005: val_loss did not improve from 6.77999
# 177316/177316 - 511s - loss: 6.6975 - val_loss: 6.7971
# Epoch 6/10
#
# Epoch 00006: val_loss improved from 6.77999 to 6.74548, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.934_gc100_e100_h100-50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 512s - loss: 6.6544 - val_loss: 6.7455
# Epoch 7/10
#
# Epoch 00007: val_loss improved from 6.74548 to 6.66156, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.934_gc100_e100_h100-50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 510s - loss: 6.6176 - val_loss: 6.6616
# Epoch 8/10
#
# Epoch 00008: val_loss improved from 6.66156 to 6.64150, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.934_gc100_e100_h100-50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 510s - loss: 6.5807 - val_loss: 6.6415
# Epoch 9/10
#
# Epoch 00009: val_loss improved from 6.64150 to 6.57112, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.934_gc100_e100_h100-50_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 514s - loss: 6.5387 - val_loss: 6.5711
# Epoch 10/10
#
# Epoch 00010: val_loss did not improve from 6.57112
# 177316/177316 - 511s - loss: 6.4992 - val_loss: 6.5881
# [6.941021898812612, 6.891827216635981, 6.82239391637603, 6.765996680242171, 6.697491021941448, 6.654378436538905, 6.61761459468136, 6.580683579787274, 6.538698359042841, 6.499166378616391]
# Opening file (1)
# RNN with categorical cross entropy 0 batchs,  5148.743968009949  epochs in 5156.047249078751 s
# Last train cost :  6.700927208267501
# recall :  0.04552361986618588
# precision :  0.0742448330683628
# sps :  0.05405405405405406
# Best  sps :  0.05405405405405406
# user_coverage :  0.48171701112877585
# item_coverage :  121
# ndcg :  0.08006027188947608
# blockbuster_share :  0.40471092077087795
# -----------------
# Save model in ks-cooks-1y/models/rnn_cce_ml60_bs32_ne5148.744_gc100_e100_h100-50_Ug_lr0.1_nt1.hdf5

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --r_emb 100 --min_iter 10 --r_l 200-100
# Out:
# 2019-12-10 00:21:58.861478: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-10 00:21:58.887387: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 1895585000 Hz
# 2019-12-10 00:21:58.887941: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x4d5c6d0 executing computations on platform Host. Devices:
# 2019-12-10 00:21:58.887997: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 177316 samples, validate on 629 samples
# Epoch 1/10
#
# Epoch 00001: val_loss improved from inf to 6.89692, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.906_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 1137s - loss: 6.9429 - val_loss: 6.8969
# Epoch 2/10
#
# Epoch 00002: val_loss did not improve from 6.89692
# 177316/177316 - 1143s - loss: 6.8892 - val_loss: 6.9138
# Epoch 3/10
#
# Epoch 00003: val_loss improved from 6.89692 to 6.84832, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.906_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 1175s - loss: 6.8562 - val_loss: 6.8483
# Epoch 4/10
#
# Epoch 00004: val_loss improved from 6.84832 to 6.82690, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.906_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 1187s - loss: 6.8033 - val_loss: 6.8269
# Epoch 5/10
#
# Epoch 00005: val_loss improved from 6.82690 to 6.78961, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.906_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 1190s - loss: 6.7582 - val_loss: 6.7896
# Epoch 6/10
#
# Epoch 00006: val_loss did not improve from 6.78961
# 177316/177316 - 1193s - loss: 6.6945 - val_loss: 6.8398
# Epoch 7/10
#
# Epoch 00007: val_loss improved from 6.78961 to 6.69742, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.906_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 1189s - loss: 6.6445 - val_loss: 6.6974
# Epoch 8/10
#
# Epoch 00008: val_loss improved from 6.69742 to 6.65340, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.906_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 1190s - loss: 6.6028 - val_loss: 6.6534
# Epoch 9/10
#
# Epoch 00009: val_loss improved from 6.65340 to 6.60940, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.906_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 1205s - loss: 6.5593 - val_loss: 6.6094
# Epoch 10/10
#
# Epoch 00010: val_loss improved from 6.60940 to 6.59501, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.906_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 1213s - loss: 6.5168 - val_loss: 6.5950
# [6.942856109968693, 6.8891948290957, 6.856238299858191, 6.803264612326398, 6.758234098119017, 6.694496739254623, 6.644488935249637, 6.602780282746156, 6.559348048878548, 6.516766975286831]
# Opening file (1)
# RNN with categorical cross entropy 0 batchs,  11823.501973867416  epochs in 11832.718838214874 s
# Last train cost :  6.726766893078379
# recall :  0.04713615724814235
# precision :  0.07742448330683656
# sps :  0.03815580286168521
# Best  sps :  0.03815580286168521
# user_coverage :  0.5023847376788553
# item_coverage :  125
# ndcg :  0.08088530635614882
# blockbuster_share :  0.4004106776180698
# -----------------
# Save model in ks-cooks-1y/models/rnn_cce_ml60_bs32_ne11823.502_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5

# %%
# !git pull origin remote_PC
# !git add .
# !git commit -m 'Remote PC_hidden_unit try multilay layers'
# !git push -u origin remote_PC
# Out:
# Von https://github.com/stgong/RNN-model
#  * branch            remote_PC  -> FETCH_HEAD
# Bereits aktuell.
# [remote_PC d47e946] Remote PC_hidden_unit try multilay layers
#  Committer: nicolakang <nicolakang@mailbox.tu-berlin.de>
# Ihr Name und E-Mail Adresse wurden automatisch auf Basis
# Ihres Benutzer- und Rechnernamens konfiguriert. Bitte prüfen Sie, dass
# diese zutreffend sind. Sie können diese Meldung unterdrücken, indem Sie
# diese explizit setzen:
#
#     git config --global user.name "Ihr Name"
#     git config --global user.email ihre@emailadresse.de
#
# Nachdem Sie das getan haben, können Sie Ihre Identität für diesen Commit ändern:
#
#     git commit --amend --reset-author
#
#  5 files changed, 113 insertions(+), 4 deletions(-)
#  create mode 100644 ks-cooks-1y/models/rnn_cce_ml60_bs32_ne11823.502_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
#  create mode 100644 ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.906_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
#  create mode 100644 ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.934_gc100_e100_h100-50_Ug_lr0.1_nt1.hdf5
#  create mode 100644 ks-cooks-1y/models/rnn_cce_ml60_bs32_ne5148.744_gc100_e100_h100-50_Ug_lr0.1_nt1.hdf5
# Zähle Objekte: 9, Fertig.
# Delta compression using up to 4 threads.
# Komprimiere Objekte: 100% (9/9), Fertig.
# Schreibe Objekte: 100% (9/9), 9.03 MiB | 5.08 MiB/s, Fertig.
# Total 9 (delta 5), reused 0 (delta 0)
# remote: Resolving deltas: 100% (5/5), completed with 4 local objects.
# To https://github.com/stgong/RNN-model.git
#    e5e014b..d47e946  remote_PC -> remote_PC
# Branch 'remote_PC' folgt nun Remote-Branch 'remote_PC' von 'origin'.
