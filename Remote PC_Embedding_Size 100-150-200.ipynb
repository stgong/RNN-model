# %% [markdown]
# ### model.fit() fine tune the RNN hidden layer parameter
# #### layers = [200, 250, 300,'200-100','300-200','200-100-50', '300-200-100']

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --min_iter 10 --r_l 100 --r_emb 100
# Out:
# 2019-12-09 13:10:11.320102: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-09 13:10:11.655442: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 1895585000 Hz
# 2019-12-09 13:10:11.656489: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x454d4a0 executing computations on platform Host. Devices:
# 2019-12-09 13:10:11.656541: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 177316 samples, validate on 629 samples
# Epoch 1/10
#
# Epoch 00001: val_loss improved from inf to 6.90085, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne5.678_gc100_e100_h100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 337s - loss: 6.9496 - val_loss: 6.9008
# Epoch 2/10
#
# ...

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --min_iter 10 --r_l 100 --r_emb 150
# Out:
# 2019-12-09 14:08:18.489148: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-09 14:08:18.511513: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 1895585000 Hz
# 2019-12-09 14:08:18.511936: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3767770 executing computations on platform Host. Devices:
# 2019-12-09 14:08:18.512088: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 177316 samples, validate on 629 samples
# Epoch 1/10
#
# Epoch 00001: val_loss improved from inf to 6.92350, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.958_gc100_e150_h100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 388s - loss: 6.9509 - val_loss: 6.9235
# Epoch 2/10
#
# ...

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --min_iter 10 --r_l 100 --r_emb 200
# Out:
# 2019-12-09 15:13:30.965100: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-09 15:13:30.987754: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 1895585000 Hz
# 2019-12-09 15:13:30.988145: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x407a730 executing computations on platform Host. Devices:
# 2019-12-09 15:13:30.988211: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 177316 samples, validate on 629 samples
# Epoch 1/10
#
# Epoch 00001: val_loss improved from inf to 6.94567, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne3.061_gc100_e200_h100_Ug_lr0.1_nt1.hdf5
# 177316/177316 - 442s - loss: 6.9505 - val_loss: 6.9457
# Epoch 2/10
#
# Epoch 00002: val_loss did not improve from 6.94567
# 177316/177316 - 423s - loss: 6.9184 - val_loss: 6.9458
# Epoch 3/10
#
# ...
