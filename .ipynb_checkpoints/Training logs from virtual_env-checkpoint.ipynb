# %% [markdown]
# ### model.fit() fine tune the RNN hidden layer parameter
# #### layers = [200, 250, 300,'200-100','300-200','200-100-50', '300-200-100']

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --r_emb 100 --min_iter 10 --r_l 200
# Out:
# Using TensorFlow backend.
# 2019-12-07 00:52:29.567140: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-07 00:52:29.577221: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7feec7716ed0 executing computations on platform Host. Devices:
# 2019-12-07 00:52:29.577249: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 177316 samples, validate on 629 samples
# Epoch 1/10
#  - 456s - loss: 6.8513 - val_loss: 6.7873
#
# Epoch 00001: val_loss improved from inf to 6.78735, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.51_gc100_e100_h200_Ug_lr0.1_nt1.hdf5
# Epoch 2/10
#  - 457s - loss: 6.7118 - val_loss: 6.7647
#
# Epoch 00002: val_loss improved from 6.78735 to 6.76472, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.51_gc100_e100_h200_Ug_lr0.1_nt1.hdf5
# Epoch 3/10
#  - 457s - loss: 6.6410 - val_loss: 6.7445
#
# Epoch 00003: val_loss improved from 6.76472 to 6.74454, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.51_gc100_e100_h200_Ug_lr0.1_nt1.hdf5
# Epoch 4/10
#  - 452s - loss: 6.5775 - val_loss: 6.7258
#
# Epoch 00004: val_loss improved from 6.74454 to 6.72579, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.51_gc100_e100_h200_Ug_lr0.1_nt1.hdf5
# Epoch 5/10
#  - 451s - loss: 6.5140 - val_loss: 6.7599
#
# Epoch 00005: val_loss did not improve from 6.72579
# Epoch 6/10
#  - 461s - loss: 6.4539 - val_loss: 6.7775
#
# Epoch 00006: val_loss did not improve from 6.72579
# Epoch 7/10
#  - 459s - loss: 6.3955 - val_loss: 6.7729
#
# Epoch 00007: val_loss did not improve from 6.72579
# Epoch 8/10
#  - 461s - loss: 6.3401 - val_loss: 6.8131
#
# Epoch 00008: val_loss did not improve from 6.72579
# Epoch 9/10
#  - 461s - loss: 6.2887 - val_loss: 6.8019
#
# Epoch 00009: val_loss did not improve from 6.72579
# Epoch 10/10
#  - 461s - loss: 6.2417 - val_loss: 6.8542
#
# Epoch 00010: val_loss did not improve from 6.72579
# [6.851305040258684, 6.711789678566165, 6.641034494981019, 6.57749067048485, 6.5139684664215896, 6.453881587974433, 6.395457624520489, 6.3401119997242725, 6.2887205688287935, 6.241748464285269]
# Opening file (1)
# RNN with categorical cross entropy 0 batchs,  4575.433108091354  epochs in 4579.161817073822 s
# Last train cost :  6.501550859604556
# recall :  0.05028863503500137
# precision :  0.08108108108108142
# sps :  0.06041335453100159
# Best  sps :  0.06041335453100159
# user_coverage :  0.5325914149443561
# item_coverage :  125
# ndcg :  0.08654643623471377
# blockbuster_share :  0.5431372549019607
# -----------------
# Save model in ks-cooks-1y/models/rnn_cce_ml60_bs32_ne4575.433_gc100_e100_h200_Ug_lr0.1_nt1.hdf5

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --r_emb 100 --min_iter 10 --r_l 250
# Out:
# Using TensorFlow backend.
# 2019-12-07 02:08:54.728669: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-07 02:08:54.739609: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fbbc3db18b0 executing computations on platform Host. Devices:
# 2019-12-07 02:08:54.739647: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 177316 samples, validate on 629 samples
# Epoch 1/10
#  - 583s - loss: 6.8471 - val_loss: 6.7717
#
# Epoch 00001: val_loss improved from inf to 6.77167, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.529_gc100_e100_h250_Ug_lr0.1_nt1.hdf5
# Epoch 2/10
#  - 579s - loss: 6.7061 - val_loss: 6.7419
#
# Epoch 00002: val_loss improved from 6.77167 to 6.74188, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.529_gc100_e100_h250_Ug_lr0.1_nt1.hdf5
# Epoch 3/10
#  - 580s - loss: 6.6256 - val_loss: 6.6944
#
# Epoch 00003: val_loss improved from 6.74188 to 6.69437, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.529_gc100_e100_h250_Ug_lr0.1_nt1.hdf5
# Epoch 4/10
#  - 579s - loss: 6.5498 - val_loss: 6.7122
#
# Epoch 00004: val_loss did not improve from 6.69437
# Epoch 5/10
#  - 580s - loss: 6.4729 - val_loss: 6.7114
#
# Epoch 00005: val_loss did not improve from 6.69437
# Epoch 6/10
#  - 580s - loss: 6.3982 - val_loss: 6.7748
#
# Epoch 00006: val_loss did not improve from 6.69437
# Epoch 7/10
#  - 581s - loss: 6.3260 - val_loss: 6.7660
#
# Epoch 00007: val_loss did not improve from 6.69437
# Epoch 8/10
#  - 579s - loss: 6.2596 - val_loss: 6.7830
#
# Epoch 00008: val_loss did not improve from 6.69437
# Epoch 9/10
#  - 581s - loss: 6.1971 - val_loss: 6.8434
#
# Epoch 00009: val_loss did not improve from 6.69437
# Epoch 10/10
#  - 580s - loss: 6.1396 - val_loss: 6.8562
#
# Epoch 00010: val_loss did not improve from 6.69437
# [6.847058830342122, 6.70614441185124, 6.625552197458318, 6.549792518724151, 6.472939310622663, 6.398184414028667, 6.3260183810122825, 6.259565211984967, 6.197053704966026, 6.139557989465088]
# Opening file (1)
# RNN with categorical cross entropy 0 batchs,  5802.175468206406  epochs in 5806.101812124252 s
# Last train cost :  6.452186697045552
# recall :  0.04724731940461061
# precision :  0.07440381558028641
# sps :  0.046104928457869634
# Best  sps :  0.046104928457869634
# user_coverage :  0.4769475357710652
# item_coverage :  131
# ndcg :  0.07766047515044587
# blockbuster_share :  0.48504273504273504
# -----------------
# Save model in ks-cooks-1y/models/rnn_cce_ml60_bs32_ne5802.175_gc100_e100_h250_Ug_lr0.1_nt1.hdf5

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --r_emb 100 --min_iter 10 --r_l 300
# Out:
# Using TensorFlow backend.
# 2019-12-07 03:45:46.803054: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-07 03:45:46.814537: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7ff6d58265f0 executing computations on platform Host. Devices:
# 2019-12-07 03:45:46.814556: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 177316 samples, validate on 629 samples
# Epoch 1/10
#  - 889s - loss: 6.8592 - val_loss: 6.7610
#
# Epoch 00001: val_loss improved from inf to 6.76098, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.491_gc100_e100_h300_Ug_lr0.1_nt1.hdf5
# Epoch 2/10
#  - 881s - loss: 6.7210 - val_loss: 6.7292
#
# Epoch 00002: val_loss improved from 6.76098 to 6.72922, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.491_gc100_e100_h300_Ug_lr0.1_nt1.hdf5
# Epoch 3/10
#  - 875s - loss: 6.6468 - val_loss: 6.7533
#
# Epoch 00003: val_loss did not improve from 6.72922
# Epoch 4/10
#  - 874s - loss: 6.5729 - val_loss: 6.7401
#
# Epoch 00004: val_loss did not improve from 6.72922
# Epoch 5/10
#  - 879s - loss: 6.4941 - val_loss: 6.7586
#
# Epoch 00005: val_loss did not improve from 6.72922
# Epoch 6/10
#  - 879s - loss: 6.4114 - val_loss: 6.7581
#
# Epoch 00006: val_loss did not improve from 6.72922
# Epoch 7/10
#  - 881s - loss: 6.3303 - val_loss: 6.8194
#
# Epoch 00007: val_loss did not improve from 6.72922
# Epoch 8/10
#  - 883s - loss: 6.2528 - val_loss: 6.8350
#
# Epoch 00008: val_loss did not improve from 6.72922
# Epoch 9/10
#  - 879s - loss: 6.1794 - val_loss: 6.8814
#
# Epoch 00009: val_loss did not improve from 6.72922
# Epoch 10/10
#  - 883s - loss: 6.1109 - val_loss: 6.9816
#
# Epoch 00010: val_loss did not improve from 6.72922
# [6.859188076617708, 6.7210114213652234, 6.646788537363795, 6.5728554262245025, 6.494119364424302, 6.411405292929124, 6.330307119609985, 6.252839487903604, 6.179352942341118, 6.110879650504072]
# Opening file (1)
# RNN with categorical cross entropy 0 batchs,  8801.997524023056  epochs in 8806.307275056839 s
# Last train cost :  6.457874731928344
# recall :  0.04538775837979153
# precision :  0.07233704292527846
# sps :  0.06995230524642289
# Best  sps :  0.06995230524642289
# user_coverage :  0.4769475357710652
# item_coverage :  119
# ndcg :  0.07901599526222346
# blockbuster_share :  0.5010989010989011
# -----------------
# Save model in ks-cooks-1y/models/rnn_cce_ml60_bs32_ne8801.998_gc100_e100_h300_Ug_lr0.1_nt1.hdf5

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --r_emb 100 --min_iter 10 --r_l 200-100
# Out:
# Using TensorFlow backend.
# 2019-12-07 06:12:39.069255: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-07 06:12:39.082020: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fed507a9bb0 executing computations on platform Host. Devices:
# 2019-12-07 06:12:39.082059: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 177316 samples, validate on 629 samples
# Epoch 1/10
#  - 747s - loss: 6.8919 - val_loss: 6.8491
#
# Epoch 00001: val_loss improved from inf to 6.84909, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.545_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# Epoch 2/10
#  - 745s - loss: 6.7943 - val_loss: 6.7919
#
# Epoch 00002: val_loss improved from 6.84909 to 6.79193, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.545_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# Epoch 3/10
#  - 744s - loss: 6.7441 - val_loss: 6.7540
#
# Epoch 00003: val_loss improved from 6.79193 to 6.75404, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.545_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# Epoch 4/10
#  - 4274s - loss: 6.7114 - val_loss: 6.7519
#
# Epoch 00004: val_loss improved from 6.75404 to 6.75187, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.545_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# Epoch 5/10
#  - 2906s - loss: 6.6794 - val_loss: 6.7258
#
# Epoch 00005: val_loss improved from 6.75187 to 6.72582, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.545_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# Epoch 6/10
#  - 1056s - loss: 6.6499 - val_loss: 6.7229
#
# Epoch 00006: val_loss improved from 6.72582 to 6.72294, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.545_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# Epoch 7/10
#  - 779s - loss: 6.6186 - val_loss: 6.7430
#
# Epoch 00007: val_loss did not improve from 6.72294
# Epoch 8/10
#  - 760s - loss: 6.5935 - val_loss: 6.7171
#
# Epoch 00008: val_loss improved from 6.72294 to 6.71710, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.545_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# Epoch 9/10
#  - 765s - loss: 6.5652 - val_loss: 6.6969
#
# Epoch 00009: val_loss improved from 6.71710 to 6.69690, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.545_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5
# Epoch 10/10
#  - 756s - loss: 6.5386 - val_loss: 6.7535
#
# Epoch 00010: val_loss did not improve from 6.69690
# [6.891874673394568, 6.794267667036644, 6.7440680759619855, 6.711395749813645, 6.679429344262956, 6.649857693638856, 6.618637937811985, 6.593521377628275, 6.565231318831909, 6.538642603990315]
# Opening file (1)
# RNN with categorical cross entropy 0 batchs,  13532.561289787292  epochs in 13539.399791002274 s
# Last train cost :  6.678692644237112
# recall :  0.05192771730187121
# precision :  0.08155802861685253
# sps :  0.06518282988871224
# Best  sps :  0.06518282988871224
# user_coverage :  0.5325914149443561
# item_coverage :  106
# ndcg :  0.08742006088417636
# blockbuster_share :  0.557504873294347
# -----------------
# Save model in ks-cooks-1y/models/rnn_cce_ml60_bs32_ne13532.561_gc100_e100_h200-100_Ug_lr0.1_nt1.hdf5

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --r_emb 100 --min_iter 10 --r_l 200-100-50
# Out:
# Using TensorFlow backend.
# 2019-12-07 11:43:20.385617: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-07 11:43:20.397452: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f9c9a055570 executing computations on platform Host. Devices:
# 2019-12-07 11:43:20.397488: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 177316 samples, validate on 629 samples
# Epoch 1/10
#  - 911s - loss: 6.9373 - val_loss: 6.9398
#
# Epoch 00001: val_loss improved from inf to 6.93976, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.55_gc100_e100_h200-100-50_Ug_lr0.1_nt1.hdf5
# Epoch 2/10
#  - 922s - loss: 6.8444 - val_loss: 6.8439
#
# Epoch 00002: val_loss improved from 6.93976 to 6.84394, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.55_gc100_e100_h200-100-50_Ug_lr0.1_nt1.hdf5
# Epoch 3/10
#  - 915s - loss: 6.7970 - val_loss: 6.7945
#
# Epoch 00003: val_loss improved from 6.84394 to 6.79454, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.55_gc100_e100_h200-100-50_Ug_lr0.1_nt1.hdf5
# Epoch 4/10
#  - 916s - loss: 6.7558 - val_loss: 6.7555
#
# Epoch 00004: val_loss improved from 6.79454 to 6.75549, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.55_gc100_e100_h200-100-50_Ug_lr0.1_nt1.hdf5
# Epoch 5/10
#  - 918s - loss: 6.7201 - val_loss: 6.7234
#
# Epoch 00005: val_loss improved from 6.75549 to 6.72341, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.55_gc100_e100_h200-100-50_Ug_lr0.1_nt1.hdf5
# Epoch 6/10
#  - 959s - loss: 6.6848 - val_loss: 6.7074
#
# Epoch 00006: val_loss improved from 6.72341 to 6.70740, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.55_gc100_e100_h200-100-50_Ug_lr0.1_nt1.hdf5
# Epoch 7/10
#  - 970s - loss: 6.6549 - val_loss: 6.7127
#
# Epoch 00007: val_loss did not improve from 6.70740
# Epoch 8/10
#  - 985s - loss: 6.6245 - val_loss: 6.7291
#
# Epoch 00008: val_loss did not improve from 6.70740
# Epoch 9/10
#  - 978s - loss: 6.5932 - val_loss: 6.6661
#
# Epoch 00009: val_loss improved from 6.70740 to 6.66607, saving model to ks-cooks-1y/models/rnn_cce_ml60_bs32_ne2.55_gc100_e100_h200-100-50_Ug_lr0.1_nt1.hdf5
# Epoch 10/10
#  - 966s - loss: 6.5629 - val_loss: 6.6958
#
# Epoch 00010: val_loss did not improve from 6.66607
# [6.937295567328077, 6.8444047661970435, 6.796965324385764, 6.755774807124848, 6.720084482038655, 6.684792149012872, 6.654873828233497, 6.624509984574717, 6.593151585684486, 6.562866654955732]
# Opening file (1)
# RNN with categorical cross entropy 0 batchs,  9439.583036899567  epochs in 9449.388659954071 s
# Last train cost :  6.717471914953569
# recall :  0.04991854559483489
# precision :  0.08028616852146296
# sps :  0.06518282988871224
# Best  sps :  0.06518282988871224
# user_coverage :  0.519872813990461
# item_coverage :  101
# ndcg :  0.08558005129449295
# blockbuster_share :  0.5346534653465347
# -----------------
# Save model in ks-cooks-1y/models/rnn_cce_ml60_bs32_ne9439.583_gc100_e100_h200-100-50_Ug_lr0.1_nt1.hdf5

# %%
# !python train.py -d ks-cooks-1y -b 32 --max_length 60 --r_emb 100 --min_iter 10 --r_l 300-200
